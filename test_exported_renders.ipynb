# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
depth_file_path = "/home/stefano/Data/dmsr/dinning/test/depth/d_0075.npy"
instance_mask_file_path = "/home/stefano/Data/dmsr/dinning/test/instance_mask/instance_mask_0075.npy"
# load npy
depth = np.load(depth_file_path)
instance_mask = np.load(instance_mask_file_path)

# %%
plt.imshow(instance_mask, vmax=8)
plt.colorbar()
plt.show()

# %%
plt.imshow(depth)
plt.colorbar()
plt.show()
